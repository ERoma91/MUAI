# %% [markdown]
# Autor: Erick Rodríguez Martínez
# Fecha: 20/Febrero/2023
#
# # Master Universitario en Inteligencía Artificial
# ## Percepción Computacional
# ### Actividad 3 - Evaluación de Clasificadores
#
# asdasdasdasds

# %% [markdown]
# ## Importar Librerias

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as pl
from skimage.segmentation import watershed
from skimage.color import label2rgb
from skimage.feature import peak_local_max
from skimage.filters import threshold_otsu, threshold_local, _multiotsu
from skimage.filters import threshold_minimum

from scipy import ndimage
#!pip install imutils
import imutils
import mahotas

# %% [markdown]
# ## Importar Imagenes
# ### Original Image | Gray Scale | GrayScale Histogram

# %%
#imgSRC = cv2.imread('water_coins.jpg')
#imgSRC = cv2.imread('Wharehouse2.jpg')
#
#imgSRC = cv2.imread('PackingHouse.jpeg')
#imgSRC = cv2.imread('Wharehouse.jpg')
#imgSRC = cv2.imread('PinkAvocado.jpeg')
imgSRC = cv2.imread('coins.png')


imgRGB = cv2.cvtColor(imgSRC, cv2.COLOR_BGR2RGB)
imgGray = cv2.cvtColor(imgSRC, cv2.COLOR_BGR2GRAY)

#imgGray = cv2.medianBlur(imgGray,3)

plt.figure()
plt.subplots_adjust(right = 1.7)
plt.subplot(1, 3, 1)
plt.imshow(imgRGB)
plt.title('Original Image ' + str(imgRGB.shape))

plt.subplot(1, 3, 2)
plt.imshow(imgGray, cmap='gray')
plt.title('Gray Scale ' + str(imgGray.shape))

plt.subplot(1, 3, 3)
hist = cv2.calcHist([imgSRC], [0], None, [256], [0, 256])
plt.xlim([0, 256])
plt.ylim([0, hist.max()])
plt.plot(hist)
plt.title('Gray Histogram '+ str(hist.max()) + ', ' + str(hist.size));

# %% [markdown]
# # Analisis sin preprocesamiento
# ## GrayScale | WaterShed | LocalMinima

# %%
thWaterShed = watershed(imgGray, watershed_line=True)
wSSegmentation = label2rgb(thWaterShed)
imgLocMin = mahotas.locmin((imgGray))

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(imgGray, cmap='gray')
plt.title('GrayScale');

plt.subplot(1, 3, 2)
plt.imshow(wSSegmentation)
plt.title('WaterShed Segmentation');

plt.subplot(1, 3, 3)
plt.imshow(imgLocMin, cmap='gray')
plt.title('LocalMinima GrayScale');

# %% [markdown]
# # Detección de bordes - Sobel Algorithm
# ## SobelX | SobelY | SobelX + SobelY

# %%
sobelx = cv2.Sobel(imgGray,cv2.CV_64F,1,0,ksize=3)
sobely = cv2.Sobel(imgGray,cv2.CV_64F,0,1,ksize=3)
edgesXY = sobelx + sobely

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(sobelx, cmap='gray')
plt.title('SobleX - XEdges');

plt.subplot(1, 3, 2)
plt.imshow(sobely, cmap='gray')
plt.title('SobelY - YEdges');

plt.subplot(1, 3, 3)
plt.imshow(edgesXY, cmap='gray')
plt.title('Edges');

# %% [markdown]
# # Combinacion de Bordes
# ## BitWise | AddWeithed

# %%
abs_grad_x = cv2.convertScaleAbs(sobelx)
abs_grad_y = cv2.convertScaleAbs(sobely)
absEdges = cv2.convertScaleAbs(edgesXY)


edgeOr = cv2.bitwise_or(abs_grad_x, abs_grad_y)
grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0.0)

plt.figure(figsize = (20,50))
plt.subplots_adjust(right = 1)

plt.subplot(1, 3, 1)
plt.imshow(-edgeOr, cmap='gray')
plt.title('edgeOR');

plt.subplot(1, 3, 2)
plt.imshow(~grad, cmap='gray')
plt.title('addWeighted');

plt.subplot(1, 3, 3)
plt.imshow(~absEdges, cmap='gray')
plt.title('Edges');

# %% [markdown]
# # Calculo de Distancia
# ## x | x

# %%
ret, otsuThEdged = cv2.threshold(grad,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
print(ret)

#open = cv2.morphologyEx(otsuThEdged, cv2.MOR)
dist = cv2.distanceTransform(~otsuThEdged, cv2.DIST_L2, 0)
cv2.normalize(dist, dist, 0, 1.0, cv2.NORM_MINMAX)

#kernel = np.ones((3,3),np.uint8)
#dist = cv2.morphologyEx(dist,cv2.MORPH_CLOSE, kernel, iterations = 5)

# Normalize the distance image for range = {0.0, 1.0}
# so we can visualize and threshold it

#cv2.imshow('Distance Transform Image', dist)
#ret, dist1 = cv2.threshold(dist, 0.6*dist.max(), 255, 0)

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(absEdges, cmap='gray')
plt.title('GrayScale');

plt.subplot(1, 3, 2)
plt.imshow(-dist, cmap='gray')
plt.title('Image Binarized');

plt.subplot(1, 3, 3)
plt.imshow(-dist, cmap='gray')
plt.title('Image Binarized | Compliment');
# Out:
# 83.0

# %%
#otsuThEdged2 = threshold_otsu(edgeOr)
#print(otsuThEdged2)
#binary2 = edgeOr > otsuThEdged2

#ret, threshEdged = cv2.threshold(closing,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#print(ret)
thWsEdged = watershed(otsuThEdged, watershed_line=True, mask=dist)
wSSegEdged = label2rgb(thWsEdged)
imgLocMinEdged = mahotas.locmin((dist))

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(dist, cmap='gray')
plt.title('GrayScale');

plt.subplot(1, 3, 2)
plt.imshow(wSSegEdged)
plt.title('WaterShed Segmentation');

plt.subplot(1, 3, 3)
plt.imshow(imgLocMinEdged, cmap='gray')
plt.title('LocalMinima GrayScale');

# %%
contours, hierarchy = cv2.findContours(otsuThEdged, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)
print(contours)
#print(hierarchy)
for c in contours:
    cv2.drawContours(imgRGB, c, -1, (0, 255, 0), 2)

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(imgRGB)
plt.title('GrayScale');
# Out:
# (array([[[692, 277]],
#
#        [[692, 278]],
#
#        [[692, 279]],
#
#        [[692, 280]],
#
#        [[693, 280]],
#
#        [[694, 280]],
#
#        [[695, 280]],
#
#        [[696, 281]],
#
#        [[695, 282]],
#
#        [[694, 283]],
#
#        [[693, 284]],
#
#        [[692, 285]],
#
#        [[692, 286]],
#
#        [[692, 287]],
#
#        [[692, 288]],
#
#        [[693, 288]],
#
#        [[694, 288]],
#
#        [[695, 288]],
#
#        [[696, 288]],
#
#        [[697, 288]],
#
#        [[698, 288]],
#
#        [[699, 288]],
#
#        [[700, 288]],
#
#        [[701, 288]],
#
#        [[702, 288]],
#
#        [[703, 288]],
#
#        [[704, 288]],
#
#        [[705, 288]],
#
#        [[706, 288]],
#
#        [[707, 288]],
#
#        [[708, 287]],
#
#        [[708, 286]],
#
#        [[709, 285]],
#
#        [[710, 286]],
#
#        [[710, 287]],
#
#        [[711, 288]],
#
#        [[712, 288]],
#
#        [[713, 288]],
#
#        [[714, 288]],
#
#        [[715, 288]],
#
#        [[716, 288]],
#
#        [[717, 287]],
#
#        [[717, 286]],
#
#        [[717, 285]],
#
#        [[718, 284]],
#
#        [[718, 283]],
#
#        [[718, 282]],
#
#        [[718, 281]],
#
#        [[717, 280]],
#
#        [[717, 279]],
#
#        [[717, 278]],
#
#        [[716, 277]],
#
#        [[715, 277]],
#
#        [[714, 277]],
#
#        [[713, 277]],
#
#        [[712, 277]],
#
#        [[711, 277]],
#
#        [[710, 278]],
#
#        [[710, 279]],
#
#        [[709, 280]],
#
#        [[708, 279]],
#
#        [[708, 278]],
#
#        [[708, 277]],
#
#        [[707, 277]],
#
#        [[706, 277]],
#
#        [[705, 277]],
#
#        [[704, 277]],
#
#        [[703, 277]],
#
#        [[702, 277]],
#
#        [[701, 277]],
#
#        [[701, 278]],
#
#        [[701, 279]],
#
#        [[700, 280]],
#
#        [[699, 279]],
#
#        [[699, 278]],
#
#        [[698, 277]],
#
#        [[697, 277]],
#
#        [[696, 277]],
#
#        [[695, 277]],
#
#        [[694, 277]],
#
#        [[693, 277]]], dtype=int32), array([[[696, 287]],
#
#        [[697, 286]],
#
#        [[698, 287]],
#
#        [[697, 288]]], dtype=int32), array([[[710, 285]],
#
#        [[711, 284]],
#
#        [[712, 285]],
#
#        [[711, 286]]], dtype=int32), array([[[715, 284]],
#
#        [[716, 283]],
#
#        [[717, 284]],
#
#        [[716, 285]]], dtype=int32), array([[[706, 284]],
#
#        [[707, 283]],
#
#        [[708, 284]],
#
#        [[707, 285]]], dtype=int32), array([[[699, 282]],
#
#        [[700, 281]],
#
#        [[701, 282]],
#
#        [[701, 283]],
#
#        [[702, 283]],
#
#        [[703, 283]],
#
#        [[704, 283]],
#
#        [[705, 283]],
#
#        [[706, 284]],
#
#        [[705, 285]],
#
#        [[704, 285]],
#
#        [[703, 285]],
#
#        [[702, 285]],
#
#        [[701, 285]],
#
#        [[701, 286]],
#
#        [[701, 287]],
#
#        [[700, 288]],
#
#        [[699, 287]],
#
#        [[699, 286]],
#
#        [[698, 286]],
#
#        [[697, 285]],
#
#        [[698, 284]],
#
#        [[699, 283]]], dtype=int32), array([[[715, 281]],
#
#        [[716, 280]],
#
#        [[717, 281]],
#
#        [[716, 282]]], dtype=int32), array([[[712, 281]],
#
#        [[713, 280]],
#
#        [[714, 281]],
#
#        [[715, 282]],
#
#        [[715, 283]],
#
#        [[714, 284]],
#
#        [[713, 285]],
#
#        [[712, 284]],
#
#        [[712, 283]],
#
#        [[712, 282]]], dtype=int32), array([[[710, 280]],
#
#        [[711, 279]],
#
#        [[712, 280]],
#
#        [[711, 281]]], dtype=int32), array([[[707, 280]],
#
#        [[708, 279]],
#
#        [[709, 280]],
#
#        [[708, 281]]], dtype=int32), array([[[697, 280]],
#
#        [[698, 279]],
#
#        [[699, 280]],
#
#        [[699, 281]],
#
#        [[698, 282]],
#
#        [[697, 281]]], dtype=int32), array([[[704, 278]],
#
#        [[705, 277]],
#
#        [[706, 278]],
#
#        [[705, 279]]], dtype=int32), array([[[641, 277]],
#
#        [[641, 278]],
#
#        [[641, 279]],
#
#        [[641, 280]],
#
#        [[642, 280]],
#
#        [[643, 280]],
#
#        [[644, 280]],
#
#        [[645, 281]],
#
#        [[644, 282]],
#
#        [[643, 283]],
#
#        [[642, 284]],
#
#        [[641, 285]],
#
#        [[641, 286]],
#
#        [[641, 287]],
#
#        [[641, 288]],
#
#        [[642, 288]],
#
#        [[643, 288]],
#
#        [[644, 288]],
#
#        [[645, 288]],
#
#        [[646, 288]],
#
#        [[647, 288]],
#
#        [[648, 288]],
#
#        [[649, 288]],
#
#        [[650, 287]],
#
#        [[651, 288]],
#
#        [[652, 288]],
#
#        [[653, 288]],
#
#        [[654, 288]],
#
#        [[655, 288]],
#
#        [[656, 288]],
#
#        [[657, 287]],
#
#        [[657, 286]],
#
#        [[658, 285]],
#
#        [[659, 286]],
#
#        [[659, 287]],
#
#        [[660, 288]],
#
#        [[661, 288]],
#
#        [[662, 288]],
#
#        [[663, 288]],
#
#        [[664, 288]],
#
#        [[665, 288]],
#
#        [[666, 287]],
#
#        [[666, 286]],
#
#        [[666, 285]],
#
#        [[667, 284]],
#
#        [[667, 283]],
#
#        [[667, 282]],
#
#        [[667, 281]],
#
#        [[666, 280]],
#
#        [[666, 279]],
#
#        [[666, 278]],
#
#        [[665, 277]],
#
#        [[664, 277]],
#
#        [[663, 277]],
#
#        [[662, 277]],
#
#        [[661, 277]],
#
#        [[660, 277]],
#
#        [[659, 278]],
#
#        [[659, 279]],
#
#        [[658, 280]],
#
#        [[657, 279]],
#
#        [[657, 278]],
#
#        [[656, 277]],
#
#        [[655, 277]],
#
#        [[654, 277]],
#
#        [[653, 277]],
#
#        [[652, 277]],
#
#        [[651, 277]],
#
#        [[650, 278]],
#
#        [[650, 279]],
#
#        [[649, 280]],
#
#        [[648, 279]],
#
#        [[648, 278]],
#
#        [[647, 277]],
#
#        [[646, 277]],
#
#        [[645, 277]],
#
#        [[644, 277]],
#
#        [[643, 277]],
#
#        [[642, 277]]], dtype=int32), array([[[645, 287]],
#
#        [[646, 286]],
#
#        [[647, 287]],
#
#        [[646, 288]]], dtype=int32), array([[[659, 285]],
#
#        [[660, 284]],
#
#        [[661, 285]],
#
#        [[660, 286]]], dtype=int32), array([[[655, 285]],
#
#        [[656, 284]],
#
#        [[657, 285]],
#
#        [[656, 286]]], dtype=int32), array([[[664, 284]],
#
#        [[665, 283]],
#
#        [[666, 284]],
#
#        [[665, 285]]], dtype=int32), array([[[650, 284]],
#
#        [[651, 283]],
#
#        [[652, 284]],
#
#        [[651, 285]]], dtype=int32), array([[[647, 284]],
#
#        [[648, 283]],
#
#        [[649, 284]],
#
#        [[650, 285]],
#
#        [[649, 286]],
#
#        [[648, 286]],
#
#        [[647, 286]],
#
#        [[646, 285]]], dtype=int32), array([[[657, 282]],
#
#        [[658, 281]],
#
#        [[659, 282]],
#
#        [[659, 283]],
#
#        [[658, 284]],
#
#        [[657, 283]]], dtype=int32), array([[[664, 281]],
#
#        [[665, 280]],
#
#        [[666, 281]],
#
#        [[665, 282]]], dtype=int32), array([[[661, 281]],
#
#        [[662, 280]],
#
#        [[663, 281]],
#
#        [[664, 282]],
#
#        [[664, 283]],
#
#        [[663, 284]],
#
#        [[662, 285]],
#
#        [[661, 284]],
#
#        [[661, 283]],
#
#        [[661, 282]]], dtype=int32), array([[[653, 281]],
#
#        [[654, 280]],
#
#        [[655, 281]],
#
#        [[655, 282]],
#
#        [[655, 283]],
#
#        [[655, 284]],
#
#        [[654, 285]],
#
#        [[653, 284]],
#
#        [[652, 283]],
#
#        [[652, 282]]], dtype=int32), array([[[650, 281]],
#
#        [[651, 280]],
#
#        [[652, 281]],
#
#        [[651, 282]]], dtype=int32), array([[[648, 281]],
#
#        [[649, 280]],
#
#        [[650, 281]],
#
#        [[649, 282]]], dtype=int32), array([[[659, 280]],
#
#        [[660, 279]],
#
#        [[661, 280]],
#
#        [[660, 281]]], dtype=int32), array([[[655, 280]],
#
#        [[656, 279]],
#
#        [[657, 280]],
#
#        [[656, 281]]], dtype=int32), array([[[646, 280]],
#
#        [[647, 279]],
#
#        [[648, 280]],
#
#        [[648, 281]],
#
#        [[647, 282]],
#
#        [[646, 281]]], dtype=int32), array([[[591, 277]],
#
#        [[590, 278]],
#
#        [[590, 279]],
#
#        [[591, 280]],
#
#        [[592, 280]],
#
#        [[593, 281]],
#
#        [[593, 282]],
#
#        [[593, 283]],
#
#        [[593, 284]],
#
#        [[592, 285]],
#
#        [[591, 286]],
#
#        [[591, 287]],
#
#        [[591, 288]],
#
#        [[592, 288]],
#
#        [[593, 288]],
#
#        [[594, 288]],
#
#        [[595, 288]],
#
#        [[596, 288]],
#
#        [[597, 288]],
#
#        [[598, 288]],
#
#        [[599, 288]],
#
#        [[600, 288]],
#
#        [[601, 288]],
#
#        [[602, 288]],
#
#        [[603, 288]],
#
#        [[604, 288]],
#
#        [[605, 287]],
#
#        [[606, 286]],
#
#        [[607, 287]],
#
#        [[608, 288]],
#
#        [[609, 288]],
#
#        [[610, 288]],
#
#        [[611, 288]],
#
#        [[612, 288]],
#
#        [[613, 288]],
#
#        [[614, 287]],
#
#        [[614, 286]],
#
#        [[615, 285]],
#
#        [[615, 284]],
#
#        [[615, 283]],
#
#        [[615, 282]],
#
#        [[615, 281]],
#
#        [[615, 280]],
#
#        [[614, 279]],
#
#        [[614, 278]],
#
#        [[613, 277]],
#
#        [[612, 277]],
#
#        [[611, 277]],
#
#        [[610, 277]],
#
#        [[609, 277]],
#
#        [[608, 277]],
#
#        [[607, 278]],
#
#        [[607, 279]],
#
#        [[606, 280]],
#
#        [[605, 279]],
#
#        [[605, 278]],
#
#        [[605, 277]],
#
#        [[604, 277]],
#
#        [[603, 277]],
#
#        [[602, 277]],
#
#        [[601, 277]],
#
#        [[600, 277]],
#
#        [[599, 277]],
#
#        [[598, 277]],
#
#        [[598, 278]],
#
#        [[598, 279]],
#
#        [[598, 280]],
#
#        [[598, 281]],
#
#        [[598, 282]],
#
#        [[598, 283]],
#
#        [[599, 283]],
#
#        [[600, 283]],
#
#        [[601, 283]],
#
#        [[602, 283]],
#
#        [[603, 284]],
#
#        [[602, 285]],
#
#        [[601, 285]],
#
#        [[600, 285]],
#
#        [[599, 285]],
#
#        [[598, 285]],
#
#        [[597, 286]],
#
#        [[596, 285]],
#
#        [[596, 284]],
#
#        [[596, 283]],
#
#        [[596, 282]],
#
#        [[596, 281]],
#
#        [[596, 280]],
#
#        [[596, 279]],
#
#        [[596, 278]],
#
#        [[595, 277]],
#
#        [[594, 277]],
#
#        [[593, 277]],
#
#        [[592, 277]]], dtype=int32), array([[[607, 285]],
#
#        [[608, 284]],
#
#        [[609, 285]],
#
#        [[608, 286]]], dtype=int32), array([[[603, 285]],
#
#        [[604, 284]],
#
#        [[605, 285]],
#
#        [[604, 286]]], dtype=int32), array([[[605, 284]],
#
#        [[606, 283]],
#
#        [[607, 284]],
#
#        [[606, 285]]], dtype=int32), array([[[603, 283]],
#
#        [[604, 282]],
#
#        [[605, 283]],
#
#        [[604, 284]]], dtype=int32), array([[[609, 281]],
#
#        [[610, 280]],
#
#        [[611, 280]],
#
#        [[612, 281]],
#
#        [[612, 282]],
#
#        [[612, 283]],
#
#        [[612, 284]],
#
#        [[611, 285]],
#
#        [[610, 285]],
#
#        [[609, 284]],
#
#        [[609, 283]],
#
#        [[609, 282]]], dtype=int32), array([[[607, 280]],
#
#        [[608, 279]],
#
#        [[609, 280]],
#
#        [[608, 281]]], dtype=int32), array([[[604, 280]],
#
#        [[605, 279]],
#
#        [[606, 280]],
#
#        [[605, 281]]], dtype=int32), array([[[601, 278]],
#
#        [[602, 277]],
#
#        [[603, 278]],
#
#        [[602, 279]]], dtype=int32), array([[[540, 277]],
#
#        [[539, 278]],
#
#        [[539, 279]],
#
#        [[540, 280]],
#
#        [[541, 280]],
#
#        [[542, 281]],
#
#        [[542, 282]],
#
#        [[542, 283]],
#
#        [[542, 284]],
#
#        [[541, 285]],
#
#        [[540, 286]],
#
#        [[540, 287]],
#
#        [[540, 288]],
#
#        [[541, 288]],
#
#        [[542, 288]],
#
#        [[543, 288]],
#
#        [[544, 288]],
#
#        [[545, 288]],
#
#        [[546, 288]],
#
#        [[547, 288]],
#
#        [[548, 288]],
#
#        [[549, 288]],
#
#        [[550, 288]],
#
#        [[551, 288]],
#
#        [[552, 288]],
#
#        [[553, 288]],
#
#        [[554, 287]],
#
#        [[555, 286]],
#
#        [[556, 287]],
#
#        [[557, 288]],
#
#        [[558, 288]],
#
#        [[559, 288]],
#
#        [[560, 288]],
#
#        [[561, 288]],
#
#        [[562, 288]],
#
#        [[563, 287]],
#
#        [[563, 286]],
#
#        [[564, 285]],
#
#        [[564, 284]],
#
#        [[564, 283]],
#
#        [[564, 282]],
#
#        [[564, 281]],
#
#        [[564, 280]],
#
#        [[563, 279]],
#
#        [[563, 278]],
#
#        [[562, 277]],
#
#        [[561, 277]],
#
#        [[560, 277]],
#
#        [[559, 277]],
#
#        [[558, 277]],
#
#        [[557, 277]],
#
#        [[556, 278]],
#
#        [[555, 279]],
#
#        [[554, 278]],
#
#        [[553, 277]],
#
#        [[552, 277]],
#
#        [[551, 277]],
#
#        [[550, 277]],
#
#        [[549, 277]],
#
#        [[548, 277]],
#
#        [[547, 278]],
#
#        [[547, 279]],
#
#        [[547, 280]],
#
#        [[546, 281]],
#
#        [[545, 280]],
#
#        [[545, 279]],
#
#        [[545, 278]],
#
#        [[544, 277]],
#
#        [[543, 277]],
#
#        [[542, 277]],
#
#        [[541, 277]]], dtype=int32), array([[[548, 286]],
#
#        [[549, 285]],
#
#        [[550, 286]],
#
#        [[549, 287]]], dtype=int32), array([[[556, 285]],
#
#        [[557, 284]],
#
#        [[558, 285]],
#
#        [[557, 286]]], dtype=int32), array([[[545, 285]],
#
#        [[546, 284]],
#
#        [[547, 285]],
#
#        [[546, 286]]], dtype=int32), array([[[558, 281]],
#
#        [[559, 280]],
#
#        [[560, 280]],
#
#        [[561, 281]],
#
#        [[561, 282]],
#
#        [[561, 283]],
#
#        [[561, 284]],
#
#        [[560, 285]],
#
#        [[559, 285]],
#
#        [[558, 284]],
#
#        [[558, 283]],
#
#        [[558, 282]]], dtype=int32), array([[[550, 281]],
#
#        [[551, 280]],
#
#        [[552, 281]],
#
#        [[552, 282]],
#
#        [[552, 283]],
#
#        [[552, 284]],
#
#        [[551, 285]],
#
#        [[550, 284]],
#
#        [[549, 283]],
#
#        [[549, 282]]], dtype=int32), array([[[547, 281]],
#
#        [[548, 280]],
#
#        [[549, 281]],
#
#        [[549, 282]],
#
#        [[549, 283]],
#
#        [[549, 284]],
#
#        [[548, 285]],
#
#        [[547, 284]],
#
#        [[547, 283]],
#
#        [[547, 282]]], dtype=int32), array([[[556, 280]],
#
#        [[557, 279]],
#
#        [[558, 280]],
#
#        [[557, 281]]], dtype=int32), array([[[548, 279]],
#
#        [[549, 278]],
#
#        [[550, 279]],
#
#        [[549, 280]]], dtype=int32), array([[[492, 277]],
#
#        [[492, 278]],
#
#        [[492, 279]],
#
#        [[492, 280]],
#
#        [[492, 281]],
#
#        [[492, 282]],
#
#        [[493, 283]],
#
#        [[494, 283]],
#
#        [[495, 283]],
#
#        [[496, 283]],
#
#        [[497, 284]],
#
#        [[496, 285]],
#
#        [[495, 285]],
#
#        [[494, 285]],
#
#        [[493, 285]],
#
#        [[492, 285]],
#
#        [[492, 286]],
#
#        [[492, 287]],
#
#        [[492, 288]],
#
#        [[493, 288]],
#
#        [[494, 288]],
#
#        [[495, 288]],
#
#        [[496, 288]],
#
#        [[497, 288]],
#
#        [[498, 288]],
#
#        [[499, 287]],
#
#        [[500, 287]],
#
#        [[501, 288]],
#
#        [[502, 288]],
#
#        [[503, 288]],
#
#        [[504, 288]],
#
#        [[505, 288]],
#
#        [[506, 288]],
#
#        [[507, 287]],
#
#        [[507, 286]],
#
#        [[508, 285]],
#
#        [[508, 284]],
#
#        [[508, 283]],
#
#        [[508, 282]],
#
#        [[508, 281]],
#
#        [[508, 280]],
#
#        [[507, 279]],
#
#        [[507, 278]],
#
#        [[506, 277]],
#
#        [[505, 277]],
#
#        [[504, 277]],
#
#        [[503, 277]],
#
#        [[502, 277]],
#
#        [[501, 277]],
#
#        [[500, 278]],
#
#        [[499, 277]],
#
#        [[498, 277]],
#
#        [[497, 277]],
#
#        [[496, 277]],
#
#        [[495, 277]],
#
#        [[494, 277]],
#
#        [[493, 277]]], dtype=int32), array([[[505, 285]],
#
#        [[506, 284]],
#
#        [[507, 285]],
#
#        [[506, 286]]], dtype=int32), array([[[500, 284]],
#
#        [[501, 283]],
#
#        [[502, 284]],
#
#        [[501, 285]]], dtype=int32), array([[[503, 281]],
#
#        [[504, 280]],
#
#        [[505, 281]],
#
#        [[505, 282]],
#
#        [[505, 283]],
#
#        [[505, 284]],
#
#        [[504, 285]],
#
#        [[503, 284]],
#
#        [[502, 283]],
#
#        [[502, 282]]], dtype=int32), array([[[500, 281]],
#
#        [[501, 280]],
#
#        [[502, 281]],
#
#        [[501, 282]]], dtype=int32), array([[[505, 280]],
#
#        [[506, 279]],
#
#        [[507, 280]],
#
#        [[506, 281]]], dtype=int32), array([[[498, 280]],
#
#        [[499, 279]],
#
#        [[500, 280]],
#
#        [[499, 281]]], dtype=int32), array([[[495, 278]],
#
#        [[496, 277]],
#
#        [[497, 278]],
#
#        [[496, 279]]], dtype=int32), array([[[447, 277]],
#
#        [[446, 278]],
#
#        [[446, 279]],
#
#        [[446, 280]],
#
#        [[446, 281]],
#
#        [[446, 282]],
#
#        [[446, 283]],
#
#        [[446, 284]],
#
#        [[446, 285]],
#
#        [[446, 286]],
#
#        [[446, 287]],
#
#        [[447, 288]],
#
#        [[448, 288]],
#
#        [[449, 288]],
#
#        [[450, 288]],
#
#        [[451, 288]],
#
#        [[452, 288]],
#
#        [[453, 287]],
#
#        [[454, 286]],
#
#        [[454, 285]],
#
#        [[454, 284]],
#
#        [[454, 283]],
#
#        [[454, 282]],
#
#        [[454, 281]],
#
#        [[454, 280]],
#
#        [[454, 279]],
#
#        [[453, 278]],
#
#        [[452, 277]],
#
#        [[451, 277]],
#
#        [[450, 277]],
#
#        [[449, 277]],
#
#        [[448, 277]]], dtype=int32), array([[[447, 286]],
#
#        [[448, 285]],
#
#        [[449, 286]],
#
#        [[448, 287]]], dtype=int32), array([[[449, 281]],
#
#        [[450, 280]],
#
#        [[451, 281]],
#
#        [[451, 282]],
#
#        [[451, 283]],
#
#        [[451, 284]],
#
#        [[450, 285]],
#
#        [[449, 284]],
#
#        [[449, 283]],
#
#        [[449, 282]]], dtype=int32), array([[[447, 279]],
#
#        [[448, 278]],
#
#        [[449, 279]],
#
#        [[448, 280]]], dtype=int32), array([[[422, 251]],
#
#        [[421, 252]],
#
#        [[421, 253]],
#
#        [[421, 254]],
#
#        [[421, 255]],
#
#        [[421, 256]],
#
#        [[421, 257]],
#
#        [[421, 258]],
#
#        [[421, 259]],
#
#        [[421, 260]],
#
#        [[421, 261]],
#
#        [[422, 262]],
#
#        [[423, 262]],
#
#        [[424, 262]],
#
#        [[425, 262]],
#
#        [[426, 262]],
#
#        [[427, 262]],
#
#        [[428, 261]],
#
#        [[429, 260]],
#
#        [[429, 259]],
#
#        [[429, 258]],
#
#        [[429, 257]],
#
#        [[429, 256]],
#
#        [[429, 255]],
#
#        [[429, 254]],
#
#        [[429, 253]],
#
#        [[428, 252]],
#
#        [[427, 251]],
#
#        [[426, 251]],
#
#        [[425, 251]],
#
#        [[424, 251]],
#
#        [[423, 251]]], dtype=int32), array([[[422, 260]],
#
#        [[423, 259]],
#
#        [[424, 260]],
#
#        [[423, 261]]], dtype=int32), array([[[424, 255]],
#
#        [[425, 254]],
#
#        [[426, 255]],
#
#        [[426, 256]],
#
#        [[426, 257]],
#
#        [[426, 258]],
#
#        [[425, 259]],
#
#        [[424, 258]],
#
#        [[424, 257]],
#
#        [[424, 256]]], dtype=int32), array([[[422, 253]],
#
#        [[423, 252]],
#
#        [[424, 253]],
#
#        [[423, 254]]], dtype=int32), array([[[133, 249]]], dtype=int32), array([[[139, 248]]], dtype=int32), array([[[325, 247]],
#
#        [[326, 247]],
#
#        [[327, 247]],
#
#        [[326, 247]]], dtype=int32), array([[[360, 246]]], dtype=int32), array([[[286, 245]]], dtype=int32), array([[[227, 245]],
#
#        [[227, 246]],
#
#        [[228, 246]],
#
#        [[229, 247]],
#
#        [[228, 246]]], dtype=int32), array([[[130, 245]]], dtype=int32), array([[[313, 244]],
#
#        [[312, 245]],
#
#        [[313, 244]],
#
#        [[314, 244]],
#
#        [[315, 244]],
#
#        [[316, 244]],
#
#        [[317, 245]],
#
#        [[318, 246]],
#
#        [[317, 247]],
#
#        [[318, 247]],
#
#        [[319, 246]],
#
#        [[318, 246]],
#
#        [[317, 245]],
#
#        [[318, 244]],
#
#        [[317, 244]],
#
#        [[316, 244]],
#
#        [[315, 244]],
#
#        [[314, 244]]], dtype=int32), array([[[136, 244]]], dtype=int32), array([[[320, 243]]], dtype=int32), array([[[311, 243]]], dtype=int32), array([[[286, 243]],
#
#        [[287, 243]]], dtype=int32), array([[[284, 243]]], dtype=int32), array([[[226, 243]],
#
#        [[227, 243]]], dtype=int32), array([[[280, 242]]], dtype=int32), array([[[278, 242]]], dtype=int32), array([[[131, 242]],
#
#        [[130, 243]],
#
#        [[131, 242]],
#
#        [[132, 242]],
#
#        [[133, 242]],
#
#        [[134, 242]],
#
#        [[133, 242]],
#
#        [[132, 242]]], dtype=int32), array([[[126, 242]],
#
#        [[125, 243]],
#
#        [[124, 243]],
#
#        [[124, 244]],
#
#        [[124, 245]],
#
#        [[125, 246]],
#
#        [[124, 245]],
#
#        [[125, 244]],
#
#        [[126, 243]],
#
#        [[127, 242]]], dtype=int32), array([[[367, 241]]], dtype=int32), array([[[288, 241]],
#
#        [[289, 241]],
#
#        [[290, 242]],
#
#        [[290, 241]],
#
#        [[289, 241]]], dtype=int32), array([[[137, 241]],
#
#        [[136, 242]],
#
#        [[137, 242]],
#
#        [[138, 243]],
#
#        [[138, 244]],
#
#        [[138, 245]],
#
#        [[138, 244]],
#
#        [[138, 243]],
#
#        [[138, 242]],
#
#        [[138, 241]]], dtype=int32), array([[[272, 240]],
#
#        [[273, 240]],
#
#        [[274, 240]],
#
#        [[273, 240]]], dtype=int32), array([[[243, 240]],
#
#        [[242, 241]],
#
#        [[242, 242]],
#
#        [[243, 241]]], dtype=int32), array([[[133, 240]]], dtype=int32), array([[[313, 239]],
#
#        [[313, 240]],
#
#        [[313, 241]],
#
#        [[313, 240]]], dtype=int32), array([[[212, 239]]], dtype=int32), array([[[122, 239]]], dtype=int32), array([[[367, 238]],
#
#        [[368, 239]],
#
#        [[369, 240]],
#
#        [[370, 241]],
#
#        [[369, 240]],
#
#        [[368, 239]]], dtype=int32), array([[[359, 238]],
#
#        [[358, 239]],
#
#        [[358, 240]],
#
#        [[358, 241]],
#
#        [[357, 242]],
#
#        [[358, 241]],
#
#        [[358, 240]],
#
#        [[359, 239]]], dtype=int32), array([[[138, 238]],
#
#        [[138, 239]]], dtype=int32), array([[[133, 238]]], dtype=int32), array([[[127, 238]],
#
#        [[128, 239]],
#
#        [[128, 238]]], dtype=int32), array([[[369, 237]],
#
#        [[370, 238]],
#
#        [[371, 239]],
#
#        [[372, 240]],
#
#        [[373, 241]],
#
#        [[372, 240]],
#
#        [[372, 239]],
#
#        [[371, 238]],
#
#        [[370, 238]]], dtype=int32), array([[[308, 237]]], dtype=int32), array([[[310, 236]],
#
#        [[310, 237]]], dtype=int32), array([[[213, 236]],
#
#        [[212, 237]]], dtype=int32), array([[[148, 236]],
#
#        [[148, 237]],
#
#        [[147, 238]],
#
#        [[147, 239]],
#
#        [[148, 239]],
#
#        [[149, 239]],
#
#        [[149, 238]],
#
#        [[149, 237]],
#
#        [[149, 236]]], dtype=int32), array([[[147, 238]],
#
#        [[148, 237]],
#
#        [[149, 238]],
#
#        [[148, 239]]], dtype=int32), array([[[359, 235]]], dtype=int32), array([[[316, 235]],
#
#        [[315, 236]],
#
#        [[314, 236]],
#
#        [[313, 237]],
#
#        [[312, 237]],
#
#        [[313, 237]],
#
#        [[314, 237]],
#
#        [[315, 236]],
#
#        [[316, 236]],
#
#        [[317, 236]],
#
#        [[318, 237]],
#
#        [[319, 238]],
#
#        [[320, 238]],
#
#        [[319, 237]],
#
#        [[318, 236]],
#
#        [[318, 235]],
#
#        [[317, 235]]], dtype=int32), array([[[225, 235]]], dtype=int32), array([[[211, 235]]], dtype=int32), array([[[170, 235]]], dtype=int32), array([[[349, 234]],
#
#        [[350, 235]],
#
#        [[351, 236]],
#
#        [[350, 237]],
#
#        [[351, 238]],
#
#        [[351, 239]],
#
#        [[352, 239]],
#
#        [[353, 240]],
#
#        [[353, 241]],
#
#        [[352, 242]],
#
#        [[353, 241]],
#
#        [[354, 242]],
#
#        [[354, 243]],
#
#        [[354, 242]],
#
#        [[355, 241]],
#
#        [[356, 240]],
#
#        [[355, 239]],
#
#        [[355, 238]],
#
#        [[354, 237]],
#
#        [[353, 236]],
#
#        [[353, 237]],
#
#        [[352, 238]],
#
#        [[351, 237]],
#
#        [[351, 236]],
#
#        [[350, 235]]], dtype=int32), array([[[353, 239]],
#
#        [[354, 238]],
#
#        [[355, 239]],
#
#        [[355, 240]],
#
#        [[354, 241]],
#
#        [[353, 240]]], dtype=int32), array([[[352, 238]],
#
#        [[353, 237]],
#
#        [[354, 238]],
#
#        [[353, 239]]], dtype=int32), array([[[290, 234]],
#
#        [[290, 235]]], dtype=int32), array([[[235, 234]],
#
#        [[235, 235]],
#
#        [[235, 236]],
#
#        [[234, 237]],
#
#        [[233, 238]],
#
#        [[232, 238]],
#
#        [[231, 237]],
#
#        [[230, 236]],
#
#        [[229, 237]],
#
#        [[230, 237]],
#
#        [[231, 238]],
#
#        [[230, 239]],
#
#        [[229, 239]],
#
#        [[230, 240]],
#
#        [[231, 241]],
#
#        [[230, 242]],
#
#        [[229, 243]],
#
#        [[229, 244]],
#
#        [[230, 245]],
#
#        [[231, 246]],
#
#        [[231, 247]],
#
#        [[231, 246]],
#
#        [[231, 245]],
#
#        [[231, 244]],
#
#        [[231, 243]],
#
#        [[231, 242]],
#
#        [[232, 241]],
#
#        [[233, 242]],
#
#        [[233, 243]],
#
#        [[233, 244]],
#
#        [[233, 245]],
#
#        [[233, 246]],
#
#        [[233, 245]],
#
#        [[234, 244]],
#
#        [[234, 243]],
#
#        [[234, 242]],
#
#        [[234, 241]],
#
#        [[234, 240]],
#
#        [[233, 240]],
#
#        [[232, 240]],
#
#        [[231, 240]],
#
#        [[230, 239]],
#
#        [[231, 238]],
#
#        [[232, 238]],
#
#        [[233, 238]],
#
#        [[234, 238]],
#
#        [[235, 238]],
#
#        [[234, 237]],
#
#        [[235, 236]],
#
#        [[236, 236]],
#
#        [[237, 236]],
#
#        [[238, 237]],
#
#        [[237, 238]],
#
#        [[238, 238]],
#
#        [[238, 237]],
#
#        [[238, 236]],
#
#        [[237, 235]],
#
#        [[236, 235]]], dtype=int32), array([[[352, 233]]], dtype=int32), array([[[314, 233]]], dtype=int32), array([[[292, 233]]], dtype=int32), array([[[371, 232]]], dtype=int32), array([[[356, 232]]], dtype=int32), array([[[276, 232]]], dtype=int32), array([[[265, 232]],
#
#        [[265, 233]]], dtype=int32), array([[[139, 232]]], dtype=int32), array([[[274, 231]]], dtype=int32), array([[[272, 231]]], dtype=int32), array([[[183, 231]]], dtype=int32), array([[[136, 231]],
#
#        [[137, 232]]], dtype=int32), array([[[125, 231]]], dtype=int32), array([[[268, 230]],
#
#        [[268, 231]],
#
#        [[269, 232]],
#
#        [[270, 233]],
#
#        [[270, 234]],
#
#        [[271, 235]],
#
#        [[272, 235]],
#
#        [[271, 234]],
#
#        [[270, 233]],
#
#        [[270, 232]],
#
#        [[269, 231]]], dtype=int32), array([[[238, 230]]], dtype=int32), array([[[175, 230]],
#
#        [[176, 230]]], dtype=int32), array([[[272, 229]]], dtype=int32), array([[[141, 229]]], dtype=int32), array([[[123, 229]]], dtype=int32), array([[[137, 228]],
#
#        [[137, 229]]], dtype=int32), array([[[132, 228]],
#
#        [[131, 229]],
#
#        [[132, 230]],
#
#        [[133, 230]],
#
#        [[132, 229]]], dtype=int32), array([[[324, 226]]], dtype=int32), array([[[320, 226]],
#
#        [[321, 226]],
#
#        [[322, 227]],
#
#        [[321, 226]]], dtype=int32), array([[[307, 226]]], dtype=int32), array([[[233, 226]]], dtype=int32), array([[[189, 226]],
#
#        [[189, 227]],
#
#        [[188, 228]],
#
#        [[188, 229]],
#
#        [[188, 230]],
#
#        [[187, 231]],
#
#        [[186, 231]],
#
#        [[186, 232]],
#
#        [[187, 231]],
#
#        [[188, 231]],
#
#        [[188, 230]],
#
#        [[188, 229]],
#
#        [[189, 228]],
#
#        [[190, 227]],
#
#        [[191, 228]],
#
#        [[192, 229]],
#
#        [[191, 230]],
#
#        [[191, 231]],
#
#        [[191, 232]],
#
#        [[192, 232]],
#
#        [[193, 232]],
#
#        [[192, 232]],
#
#        [[191, 231]],
#
#        [[192, 230]],
#
#        [[192, 229]],
#
#        [[192, 228]],
#
#        [[191, 227]],
#
#        [[190, 227]]], dtype=int32), array([[[126, 226]]], dtype=int32), array([[[329, 225]],
#
#        [[330, 226]],
#
#        [[330, 227]],
#
#        [[330, 228]],
#
#        [[331, 229]],
#
#        [[331, 230]],
#
#        [[331, 231]],
#
#        [[331, 232]],
#
#        [[330, 233]],
#
#        [[331, 233]],
#
#        [[331, 232]],
#
#        [[331, 231]],
#
#        [[331, 230]],
#
#        [[331, 229]],
#
#        [[331, 228]],
#
#        [[330, 227]],
#
#        [[330, 226]]], dtype=int32), array([[[326, 225]],
#
#        [[326, 226]]], dtype=int32), array([[[310, 225]],
#
#        [[309, 226]],
#
#        [[309, 227]],
#
#        [[309, 228]],
#
#        [[309, 229]],
#
#        [[308, 230]],
#
#        [[309, 231]],
#
#        [[309, 232]],
#
#        [[309, 233]],
#
#        [[310, 234]],
#
#        [[311, 233]],
#
#        [[312, 233]],
#
#        [[312, 232]],
#
#        [[313, 231]],
#
#        [[314, 231]],
#
#        [[315, 230]],
#
#        [[316, 231]],
#
#        [[317, 232]],
#
#        [[318, 233]],
#
#        [[319, 233]],
#
#        [[320, 234]],
#
#        [[321, 234]],
#
#        [[322, 235]],
#
#        [[322, 236]],
#
#        [[323, 235]],
#
#        [[324, 236]],
#
#        [[324, 237]],
#
#        [[324, 238]],
#
#        [[323, 239]],
#
#        [[322, 238]],
#
#        [[322, 239]],
#
#        [[323, 240]],
#
#        [[324, 241]],
#
#        [[325, 242]],
#
#        [[326, 243]],
#
#        [[326, 244]],
#
#        [[327, 245]],
#
#        [[327, 244]],
#
#        [[326, 243]],
#
#        [[326, 242]],
#
#        [[326, 241]],
#
#        [[327, 240]],
#
#        [[328, 239]],
#
#        [[329, 239]],
#
#        [[330, 238]],
#
#        [[331, 237]],
#
#        [[331, 236]],
#
#        [[331, 235]],
#
#        [[330, 235]],
#
#        [[331, 236]],
#
#        [[330, 237]],
#
#        [[329, 238]],
#
#        [[328, 239]],
#
#        [[327, 238]],
#
#        [[326, 238]],
#
#        [[325, 237]],
#
#        [[324, 236]],
#
#        [[324, 235]],
#
#        [[323, 235]],
#
#        [[322, 234]],
#
#        [[321, 233]],
#
#        [[320, 233]],
#
#        [[319, 232]],
#
#        [[318, 232]],
#
#        [[317, 231]],
#
#        [[316, 230]],
#
#        [[315, 229]],
#
#        [[314, 229]],
#
#        [[313, 228]],
#
#        [[312, 228]],
#
#        [[311, 228]],
#
#        [[310, 227]],
#
#        [[310, 226]],
#
#        [[311, 225]],
#
#        [[312, 225]],
#
#        [[313, 225]],
#
#        [[314, 226]],
#
#        [[315, 227]],
#
#        [[316, 227]],
#
#        [[317, 227]],
#
#        [[318, 228]],
#
#        [[319, 228]],
#
#        [[320, 228]],
#
#        [[321, 229]],
#
#        [[321, 230]],
#
#        [[322, 230]],
#
#        [[323, 231]],
#
#        [[322, 230]],
#
#        [[321, 229]],
#
#        [[320, 228]],
#
#        [[319, 228]],
#
#        [[318, 227]],
#
#        [[317, 227]],
#
#        [[316, 227]],
#
#        [[315, 226]],
#
#        [[314, 225]],
#
#        [[313, 225]],
#
#        [[312, 225]],
#
#        [[311, 225]]], dtype=int32), array([[[324, 240]],
#
#        [[325, 239]],
#
#        [[326, 239]],
#
#        [[327, 240]],
#
#        [[326, 241]],
#
#        [[325, 241]]], dtype=int32), array([[[323, 239]],
#
#        [[324, 238]],
#
#        [[325, 239]],
#
#        [[324, 240]]], dtype=int32), array([[[309, 231]],
#
#        [[310, 230]],
#
#        [[311, 230]],
#
#        [[312, 231]],
#
#        [[311, 232]],
#
#        [[310, 232]]], dtype=int32), array([[[312, 230]],
#
#        [[313, 229]],
#
#        [[314, 229]],
#
#        [[315, 230]],
#
#        [[314, 231]],
#
#        [[313, 231]]], dtype=int32), array([[[311, 229]],
#
#        [[312, 228]],
#
#        [[313, 229]],
#
#        [[312, 230]]], dtype=int32), array([[[309, 228]],
#
#        [[310, 227]],
#
#        [[311, 228]],
#
#        [[311, 229]],
#
#        [[310, 230]],
#
#        [[309, 229]]], dtype=int32), array([[[231, 225]]], dtype=int32), array([[[187, 225]]], dtype=int32), array([[[182, 225]],
#
#        [[183, 225]],
#
#        [[184, 225]],
#
#        [[185, 226]],
#
#        [[185, 227]],
#
#        [[184, 228]],
#
#        [[183, 227]],
#
#        [[182, 228]],
#
#        [[181, 229]],
#
#        [[181, 230]],
#
#        [[182, 229]],
#
#        [[183, 228]],
#
#        [[184, 228]],
#
#        [[185, 228]],
#
#        [[185, 227]],
#
#        [[185, 226]],
#
#        [[184, 225]],
#
#        [[183, 225]]], dtype=int32), array([[[216, 224]],
#
#        [[216, 225]],
#
#        [[215, 226]],
#
#        [[215, 227]],
#
#        [[214, 228]],
#
#        [[214, 229]],
#
#        [[215, 230]],
#
#        [[216, 231]],
#
#        [[217, 232]],
#
#        [[218, 232]],
#
#        [[219, 233]],
#
#        [[219, 234]],
#
#        [[218, 235]],
#
#        [[217, 236]],
#
#        [[216, 236]],
#
#        [[216, 237]],
#
#        [[216, 238]],
#
#        [[217, 238]],
#
#        [[218, 238]],
#
#        [[217, 238]],
#
#        [[216, 237]],
#
#        [[217, 236]],
#
#        [[218, 236]],
#
#        [[219, 235]],
#
#        [[220, 236]],
#
#        [[221, 235]],
#
#        [[222, 235]],
#
#        [[223, 236]],
#
#        [[222, 237]],
#
#        [[221, 238]],
#
#        [[220, 238]],
#
#        [[220, 239]],
#
#        [[219, 240]],
#
#        [[219, 241]],
#
#        [[219, 242]],
#
#        [[218, 243]],
#
#        [[219, 244]],
#
#        [[220, 244]],
#
#        [[221, 244]],
#
#        [[222, 243]],
#
#        [[223, 243]],
#
#        [[222, 242]],
#
#        [[221, 241]],
#
#        [[222, 240]],
#
#        [[223, 240]],
#
#        [[224, 240]],
#
#        [[224, 239]],
#
#        [[224, 238]],
#
#        [[223, 237]],
#
#        [[223, 236]],
#
#        [[223, 235]],
#
#        [[222, 235]],
#
#        [[221, 234]],
#
#        [[220, 233]],
#
#        [[219, 233]],
#
#        [[218, 232]],
#
#        [[219, 231]],
#
#        [[218, 231]],
#
#        [[217, 231]],
#
#        [[216, 230]],
#
#        [[217, 229]],
#
#        [[217, 228]],
#
#        [[218, 227]],
#
#        [[218, 226]],
#
#        [[218, 225]],
#
#        [[218, 224]],
#
#        [[218, 225]],
#
#        [[218, 226]],
#
#        [[218, 227]],
#
#        [[217, 228]],
#
#        [[217, 229]],
#
#        [[216, 230]],
#
#        [[215, 229]],
#
#        [[215, 228]],
#
#        [[215, 227]],
#
#        [[216, 226]],
#
#        [[216, 225]]], dtype=int32), array([[[219, 241]],
#
#        [[220, 240]],
#
#        [[221, 241]],
#
#        [[221, 242]],
#
#        [[221, 243]],
#
#        [[220, 244]],
#
#        [[219, 243]],
#
#        [[219, 242]]], dtype=int32), array([[[220, 239]],
#
#        [[221, 238]],
#
#        [[222, 238]],
#
#        [[223, 239]],
#
#        [[222, 240]],
#
#        [[221, 241]],
#
#        [[220, 240]]], dtype=int32), array([[[222, 238]],
#
#        [[223, 237]],
#
#        [[224, 238]],
#
#        [[223, 239]]], dtype=int32), array([[[219, 234]],
#
#        [[220, 233]],
#
#        [[221, 234]],
#
#        [[221, 235]],
#
#        [[220, 236]],
#
#        [[219, 235]]], dtype=int32), array([[[179, 224]],
#
#        [[179, 225]],
#
#        [[180, 224]]], dtype=int32), array([[[136, 224]],
#
#        [[136, 225]]], dtype=int32), array([[[133, 224]],
#
#        [[133, 225]],
#
#        [[134, 226]],
#
#        [[134, 225]]], dtype=int32), array([[[321, 223]],
#
#        [[322, 223]]], dtype=int32), array([[[310, 223]]], dtype=int32), array([[[272, 223]],
#
#        [[272, 224]]], dtype=int32), array([[[137, 222]]], dtype=int32), array([[[315, 221]]], dtype=int32), array([[[131, 221]],
#
#        [[131, 222]]], dtype=int32), array([[[126, 221]]], dtype=int32), array([[[180, 219]],
#
#        [[179, 220]],
#
#        [[178, 220]],
#
#        [[177, 220]],
#
#        [[176, 220]],
#
#        [[175, 221]],
#
#        [[174, 222]],
#
#        [[173, 223]],
#
#        [[172, 223]],
#
#        [[171, 224]],
#
#        [[171, 225]],
#
#        [[170, 226]],
#
#        [[169, 227]],
#
#        [[169, 228]],
#
#        [[168, 229]],
#
#        [[168, 230]],
#
#        [[167, 231]],
#
#        [[167, 232]],
#
#        [[167, 233]],
#
#        [[167, 234]],
#
#        [[167, 235]],
#
#        [[167, 236]],
#
#        [[167, 237]],
#
#        [[167, 238]],
#
#        [[167, 239]],
#
#        [[167, 240]],
#
#        [[168, 241]],
#
#        [[168, 242]],
#
#        [[169, 243]],
#
#        [[169, 244]],
#
#        [[170, 245]],
#
#        [[171, 246]],
#
#        [[172, 247]],
#
#        [[173, 248]],
#
#        [[174, 249]],
#
#        [[175, 249]],
#
#        [[176, 249]],
#
#        [[177, 250]],
#
#        [[178, 250]],
#
#        [[179, 251]],
#
#        [[180, 251]],
#
#        [[181, 251]],
#
#        [[182, 252]],
#
#        [[183, 252]],
#
#        [[184, 252]],
#
#        [[185, 252]],
#
#        [[186, 252]],
#
#        [[187, 251]],
#
#        [[188, 251]],
#
#        [[189, 251]],
#
#        [[190, 251]],
#
#        [[191, 250]],
#
#        [[192, 250]],
#
#        [[193, 249]],
#
#        [[194, 248]],
#
#        [[195, 247]],
#
#        [[196, 246]],
#
#        [[197, 245]],
#
#        [[198, 244]],
#
#        [[198, 243]],
#
#        [[199, 242]],
#
#        [[199, 241]],
#
#        [[199, 240]],
#
#        [[200, 239]],
#
#        [[200, 238]],
#
#        [[200, 237]],
#
#        [[200, 236]],
#
#        [[200, 235]],
#
#        [[200, 234]],
#
#        [[200, 233]],
#
#        [[199, 232]],
#
#        [[199, 231]],
#
#        [[199, 230]],
#
#        [[199, 229]],
#
#        [[198, 228]],
#
#        [[197, 227]],
#
#        [[197, 226]],
#
#        [[196, 225]],
#
#        [[195, 224]],
#
#        [[194, 223]],
#
#        [[193, 222]],
#
#        [[192, 221]],
#
#        [[191, 221]],
#
#        [[190, 220]],
#
#        [[189, 220]],
#
#        [[188, 219]],
#
#        [[187, 219]],
#
#        [[186, 219]],
#
#        [[185, 219]],
#
#        [[184, 219]],
#
#        [[183, 219]],
#
#        [[182, 219]],
#
#        [[181, 219]]], dtype=int32), array([[[180, 249]],
#
#        [[181, 248]],
#
#        [[182, 248]],
#
#        [[183, 249]],
#
#        [[182, 250]],
#
#        [[181, 250]]], dtype=int32), array([[[176, 247]],
#
#        [[177, 246]],
#
#        [[178, 247]],
#
#        [[177, 248]]], dtype=int32), array([[[181, 246]],
#
#        [[182, 245]],
#
#        [[183, 245]],
#
#        [[184, 246]],
#
#        [[185, 246]],
#
#        [[186, 247]],
#
#        [[185, 248]],
#
#        [[184, 248]],
#
#        [[183, 248]],
#
#        [[182, 248]],
#
#        [[181, 248]],
#
#        [[180, 249]],
#
#        [[179, 248]],
#
#        [[179, 247]],
#
#        [[180, 246]]], dtype=int32), array([[[174, 246]],
#
#        [[175, 245]],
#
#        [[176, 246]],
#
#        [[175, 247]]], dtype=int32), array([[[177, 245]],
#
#        [[178, 244]],
#
#        [[179, 245]],
#
#        [[180, 246]],
#
#        [[179, 247]],
#
#        [[178, 247]],
#
#        [[177, 246]]], dtype=int32), array([[[173, 245]],
#
#        [[174, 244]],
#
#        [[175, 245]],
#
#        [[174, 246]]], dtype=int32), array([[[175, 242]],
#
#        [[176, 241]],
#
#        [[177, 242]],
#
#        [[177, 243]],
#
#        [[176, 244]],
#
#        [[175, 243]]], dtype=int32), array([[[174, 239]],
#
#        [[175, 238]],
#
#        [[176, 239]],
#
#        [[176, 240]],
#
#        [[175, 241]],
#
#        [[174, 240]]], dtype=int32), array([[[195, 229]],
#
#        [[196, 228]],
#
#        [[197, 229]],
#
#        [[196, 230]]], dtype=int32), array([[[174, 225]],
#
#        [[175, 224]],
#
#        [[176, 225]],
#
#        [[175, 226]]], dtype=int32), array([[[178, 222]],
#
#        [[179, 221]],
#
#        [[180, 221]],
#
#        [[181, 221]],
#
#        [[182, 221]],
#
#        [[183, 222]],
#
#        [[184, 222]],
#
#        [[185, 222]],
#
#        [[186, 223]],
#
#        [[187, 223]],
#
#        [[188, 223]],
#
#        [[189, 223]],
#
#        [[190, 223]],
#
#        [[191, 223]],
#
#        [[192, 223]],
#
#        [[193, 224]],
#
#        [[194, 225]],
#
#        [[195, 226]],
#
#        [[195, 227]],
#
#        [[196, 228]],
#
#        [[195, 229]],
#
#        [[196, 230]],
#
#        [[197, 230]],
#
#        [[198, 231]],
#
#        [[198, 232]],
#
#        [[198, 233]],
#
#        [[197, 234]],
#
#        [[198, 234]],
#
#        [[199, 235]],
#
#        [[199, 236]],
#
#        [[199, 237]],
#
#        [[198, 238]],
#
#        [[198, 239]],
#
#        [[198, 240]],
#
#        [[198, 241]],
#
#        [[197, 242]],
#
#        [[196, 243]],
#
#        [[196, 244]],
#
#        [[195, 245]],
#
#        [[194, 245]],
#
#        [[193, 245]],
#
#        [[192, 244]],
#
#        [[193, 243]],
#
#        [[194, 243]],
#
#        [[193, 242]],
#
#        [[193, 241]],
#
#        [[192, 240]],
#
#        [[192, 239]],
#
#        [[192, 238]],
#
#        [[192, 237]],
#
#        [[192, 236]],
#
#        [[192, 235]],
#
#        [[193, 234]],
#
#        [[192, 234]],
#
#        [[192, 235]],
#
#        [[191, 236]],
#
#        [[192, 237]],
#
#        [[192, 238]],
#
#        [[192, 239]],
#
#        [[192, 240]],
#
#        [[192, 241]],
#
#        [[192, 242]],
#
#        [[193, 243]],
#
#        [[192, 244]],
#
#        [[191, 244]],
#
#        [[190, 244]],
#
#        [[189, 243]],
#
#        [[190, 244]],
#
#        [[191, 244]],
#
#        [[192, 244]],
#
#        [[193, 245]],
#
#        [[194, 246]],
#
#        [[193, 247]],
#
#        [[192, 247]],
#
#        [[191, 248]],
#
#        [[190, 249]],
#
#        [[189, 249]],
#
#        [[188, 250]],
#
#        [[187, 250]],
#
#        [[186, 249]],
#
#        [[187, 248]],
#
#        [[186, 247]],
#
#        [[186, 246]],
#
#        [[187, 245]],
#
#        [[188, 245]],
#
#        [[187, 245]],
#
#        [[186, 245]],
#
#        [[185, 245]],
#
#        [[184, 244]],
#
#        [[183, 244]],
#
#        [[182, 244]],
#
#        [[181, 244]],
#
#        [[180, 243]],
#
#        [[180, 244]],
#
#        [[179, 245]],
#
#        [[178, 244]],
#
#        [[178, 243]],
#
#        [[177, 242]],
#
#        [[178, 241]],
#
#        [[177, 240]],
#
#        [[177, 239]],
#
#        [[177, 238]],
#
#        [[177, 237]],
#
#        [[177, 236]],
#
#        [[177, 235]],
#
#        [[177, 234]],
#
#        [[177, 233]],
#
#        [[178, 232]],
#
#        [[179, 232]],
#
#        [[180, 233]],
#
#        [[181, 234]],
#
#        [[182, 234]],
#
#        [[183, 234]],
#
#        [[184, 234]],
#
#        [[184, 233]],
#
#        [[183, 233]],
#
#        [[182, 233]],
#
#        [[181, 232]],
#
#        [[180, 232]],
#
#        [[179, 231]],
#
#        [[178, 231]],
#
#        [[178, 232]],
#
#        [[177, 233]],
#
#        [[176, 233]],
#
#        [[175, 233]],
#
#        [[174, 234]],
#
#        [[174, 235]],
#
#        [[174, 236]],
#
#        [[174, 237]],
#
#        [[174, 238]],
#
#        [[174, 239]],
#
#        [[174, 240]],
#
#        [[174, 241]],
#
#        [[174, 242]],
#
#        [[175, 243]],
#
#        [[174, 244]],
#
#        [[173, 245]],
#
#        [[172, 244]],
#
#        [[171, 243]],
#
#        [[170, 242]],
#
#        [[169, 241]],
#
#        [[169, 240]],
#
#        [[169, 239]],
#
#        [[168, 238]],
#
#        [[168, 237]],
#
#        [[168, 236]],
#
#        [[168, 235]],
#
#        [[168, 234]],
#
#        [[168, 233]],
#
#        [[168, 232]],
#
#        [[169, 231]],
#
#        [[170, 230]],
#
#        [[170, 229]],
#
#        [[171, 228]],
#
#        [[172, 227]],
#
#        [[172, 226]],
#
#        [[173, 225]],
#
#        [[174, 225]],
#
#        [[175, 226]],
#
#        [[176, 226]],
#
#        [[177, 225]],
#
#        [[176, 225]],
#
#        [[175, 224]],
#
#        [[176, 223]],
#
#        [[177, 222]]], dtype=int32), array([[[130, 219]]], dtype=int32), array([[[402, 218]],
#
#        [[402, 219]],
#
#        [[402, 220]],
#
#        [[402, 221]],
#
#        [[403, 221]],
#
#        [[404, 221]],
#
#        [[405, 221]],
#
#        [[406, 222]],
#
#        [[405, 223]],
#
#        [[404, 224]],
#
#        [[403, 225]],
#
#        [[402, 226]],
#
#        [[402, 227]],
#
#        [[402, 228]],
#
#        [[402, 229]],
#
#        [[403, 229]],
#
#        [[404, 229]],
#
#        [[405, 229]],
#
#        [[406, 229]],
#
#        [[407, 229]],
#
#        [[408, 229]],
#
#        [[409, 229]],
#
#        [[410, 229]],
#
#        [[411, 228]],
#
#        [[412, 229]],
#
#        [[413, 229]],
#
#        [[414, 229]],
#
#        [[415, 229]],
#
#        [[416, 229]],
#
#        [[417, 229]],
#
#        [[418, 228]],
#
#        [[418, 227]],
#
#        [[419, 226]],
#
#        [[420, 227]],
#
#        [[420, 228]],
#
#        [[421, 229]],
#
#        [[422, 229]],
#
#        [[423, 229]],
#
#        [[424, 229]],
#
#        [[425, 229]],
#
#        [[426, 229]],
#
#        [[427, 228]],
#
#        [[427, 227]],
#
#        [[427, 226]],
#
#        [[428, 225]],
#
#        [[428, 224]],
#
#        [[428, 223]],
#
#        [[428, 222]],
#
#        [[427, 221]],
#
#        [[427, 220]],
#
#        [[427, 219]],
#
#        [[426, 218]],
#
#        [[425, 218]],
#
#        [[424, 218]],
#
#        [[423, 218]],
#
#        [[422, 218]],
#
#        [[421, 218]],
#
#        [[420, 219]],
#
#        [[420, 220]],
#
#        [[419, 221]],
#
#        [[418, 220]],
#
#        [[418, 219]],
#
#        [[417, 218]],
#
#        [[416, 218]],
#
#        [[415, 218]],
#
#        [[414, 218]],
#
#        [[413, 218]],
#
#        [[412, 218]],
#
#        [[411, 219]],
#
#        [[411, 220]],
#
#        [[410, 221]],
#
#        [[409, 220]],
#
#        [[409, 219]],
#
#        [[408, 218]],
#
#        [[407, 218]],
#
#        [[406, 218]],
#
#        [[405, 218]],
#
#        [[404, 218]],
#
#        [[403, 218]]], dtype=int32), array([[[406, 228]],
#
#        [[407, 227]],
#
#        [[408, 228]],
#
#        [[407, 229]]], dtype=int32), array([[[420, 226]],
#
#        [[421, 225]],
#
#        [[422, 226]],
#
#        [[421, 227]]], dtype=int32), array([[[416, 226]],
#
#        [[417, 225]],
#
#        [[418, 226]],
#
#        [[417, 227]]], dtype=int32), array([[[425, 225]],
#
#        [[426, 224]],
#
#        [[427, 225]],
#
#        [[426, 226]]], dtype=int32), array([[[411, 225]],
#
#        [[412, 224]],
#
#        [[413, 225]],
#
#        [[412, 226]]], dtype=int32), array([[[408, 225]],
#
#        [[409, 224]],
#
#        [[410, 225]],
#
#        [[411, 226]],
#
#        [[410, 227]],
#
#        [[409, 227]],
#
#        [[408, 227]],
#
#        [[407, 226]]], dtype=int32), array([[[418, 223]],
#
#        [[419, 222]],
#
#        [[420, 223]],
#
#        [[420, 224]],
#
#        [[419, 225]],
#
#        [[418, 224]]], dtype=int32), array([[[425, 222]],
#
#        [[426, 221]],
#
#        [[427, 222]],
#
#        [[426, 223]]], dtype=int32), array([[[422, 222]],
#
#        [[423, 221]],
#
#        [[424, 222]],
#
#        [[425, 223]],
#
#        [[425, 224]],
#
#        [[424, 225]],
#
#        [[423, 226]],
#
#        [[422, 225]],
#
#        [[422, 224]],
#
#        [[422, 223]]], dtype=int32), array([[[414, 222]],
#
#        [[415, 221]],
#
#        [[416, 222]],
#
#        [[416, 223]],
#
#        [[416, 224]],
#
#        [[416, 225]],
#
#        [[415, 226]],
#
#        [[414, 225]],
#
#        [[413, 224]],
#
#        [[413, 223]]], dtype=int32), array([[[411, 222]],
#
#        [[412, 221]],
#
#        [[413, 222]],
#
#        [[412, 223]]], dtype=int32), array([[[409, 222]],
#
#        [[410, 221]],
#
#        [[411, 222]],
#
#        [[410, 223]]], dtype=int32), array([[[420, 221]],
#
#        [[421, 220]],
#
#        [[422, 221]],
#
#        [[421, 222]]], dtype=int32), array([[[416, 221]],
#
#        [[417, 220]],
#
#        [[418, 221]],
#
#        [[417, 222]]], dtype=int32), array([[[407, 221]],
#
#        [[408, 220]],
#
#        [[409, 221]],
#
#        [[409, 222]],
#
#        [[408, 223]],
#
#        [[407, 222]]], dtype=int32), array([[[141, 218]],
#
#        [[140, 219]],
#
#        [[141, 220]],
#
#        [[141, 221]],
#
#        [[142, 222]],
#
#        [[141, 223]],
#
#        [[140, 223]],
#
#        [[139, 223]],
#
#        [[140, 223]],
#
#        [[141, 224]],
#
#        [[140, 225]],
#
#        [[140, 226]],
#
#        [[140, 227]],
#
#        [[141, 227]],
#
#        [[142, 227]],
#
#        [[143, 226]],
#
#        [[144, 225]],
#
#        [[145, 226]],
#
#        [[146, 226]],
#
#        [[147, 227]],
#
#        [[146, 228]],
#
#        [[145, 228]],
#
#        [[144, 228]],
#
#        [[145, 229]],
#
#        [[146, 228]],
#
#        [[147, 228]],
#
#        [[148, 229]],
#
#        [[147, 230]],
#
#        [[147, 231]],
#
#        [[146, 232]],
#
#        [[145, 233]],
#
#        [[145, 234]],
#
#        [[144, 235]],
#
#        [[143, 234]],
#
#        [[143, 235]],
#
#        [[144, 236]],
#
#        [[144, 235]],
#
#        [[145, 234]],
#
#        [[146, 235]],
#
#        [[147, 234]],
#
#        [[147, 233]],
#
#        [[147, 232]],
#
#        [[148, 231]],
#
#        [[147, 230]],
#
#        [[148, 229]],
#
#        [[149, 229]],
#
#        [[150, 229]],
#
#        [[150, 228]],
#
#        [[149, 227]],
#
#        [[148, 227]],
#
#        [[147, 227]],
#
#        [[146, 226]],
#
#        [[145, 225]],
#
#        [[146, 224]],
#
#        [[145, 223]],
#
#        [[145, 222]],
#
#        [[144, 221]],
#
#        [[143, 222]],
#
#        [[142, 222]],
#
#        [[141, 221]],
#
#        [[141, 220]],
#
#        [[141, 219]],
#
#        [[142, 218]],
#
#        [[143, 219]],
#
#        [[144, 219]],
#
#        [[143, 219]],
#
#        [[142, 218]]], dtype=int32), array([[[148, 228]],
#
#        [[149, 227]],
#
#        [[150, 228]],
#
#        [[149, 229]]], dtype=int32), array([[[142, 225]],
#
#        [[143, 224]],
#
#        [[144, 225]],
#
#        [[143, 226]]], dtype=int32), array([[[140, 225]],
#
#        [[141, 224]],
#
#        [[142, 225]],
#
#        [[141, 226]]], dtype=int32), array([[[144, 224]],
#
#        [[145, 223]],
#
#        [[146, 224]],
#
#        [[145, 225]]], dtype=int32), array([[[143, 223]],
#
#        [[144, 222]],
#
#        [[145, 223]],
#
#        [[144, 224]]], dtype=int32), array([[[141, 223]],
#
#        [[142, 222]],
#
#        [[143, 223]],
#
#        [[142, 224]]], dtype=int32), array([[[131, 217]]], dtype=int32), array([[[275, 216]],
#
#        [[274, 217]],
#
#        [[273, 217]],
#
#        [[272, 217]],
#
#        [[271, 218]],
#
#        [[270, 218]],
#
#        [[269, 218]],
#
#        [[268, 219]],
#
#        [[267, 220]],
#
#        [[266, 221]],
#
#        [[265, 222]],
#
#        [[265, 223]],
#
#        [[264, 224]],
#
#        [[263, 225]],
#
#        [[263, 226]],
#
#        [[262, 227]],
#
#        [[262, 228]],
#
#        [[261, 229]],
#
#        [[261, 230]],
#
#        [[260, 231]],
#
#        [[260, 232]],
#
#        [[260, 233]],
#
#        [[260, 234]],
#
#        [[260, 235]],
#
#        [[260, 236]],
#
#        [[260, 237]],
#
#        [[261, 238]],
#
#        [[261, 239]],
#
#        [[262, 240]],
#
#        [[262, 241]],
#
#        [[263, 242]],
#
#        [[263, 243]],
#
#        [[264, 244]],
#
#        [[265, 245]],
#
#        [[266, 246]],
#
#        [[267, 247]],
#
#        [[268, 248]],
#
#        [[268, 249]],
#
#        [[269, 249]],
#
#        [[270, 250]],
#
#        [[271, 250]],
#
#        [[272, 251]],
#
#        [[273, 251]],
#
#        [[274, 251]],
#
#        [[275, 252]],
#
#        [[276, 252]],
#
#        [[277, 252]],
#
#        [[278, 252]],
#
#        [[279, 252]],
#
#        [[280, 252]],
#
#        [[281, 252]],
#
#        [[282, 252]],
#
#        [[283, 251]],
#
#        [[284, 251]],
#
#        [[285, 251]],
#
#        [[286, 250]],
#
#        [[287, 250]],
#
#        [[288, 249]],
#
#        [[289, 248]],
#
#        [[290, 248]],
#
#        [[291, 247]],
#
#        [[291, 246]],
#
#        [[292, 245]],
#
#        [[293, 244]],
#
#        [[294, 243]],
#
#        [[295, 242]],
#
#        [[295, 241]],
#
#        [[296, 240]],
#
#        [[296, 239]],
#
#        [[297, 238]],
#
#        [[297, 237]],
#
#        [[298, 236]],
#
#        [[298, 235]],
#
#        [[298, 234]],
#
#        [[298, 233]],
#
#        [[298, 232]],
#
#        [[298, 231]],
#
#        [[298, 230]],
#
#        [[297, 229]],
#
#        [[297, 228]],
#
#        [[297, 227]],
#
#        [[296, 226]],
#
#        [[296, 225]],
#
#        [[295, 224]],
#
#        [[295, 223]],
#
#        [[294, 222]],
#
#        [[293, 221]],
#
#        [[292, 220]],
#
#        [[291, 219]],
#
#        [[290, 219]],
#
#        [[289, 218]],
#
#        [[288, 217]],
#
#        [[287, 217]],
#
#        [[286, 216]],
#
#        [[285, 216]],
#
#        [[284, 216]],
#
#        [[283, 216]],
#
#        [[282, 216]],
#
#        [[281, 216]],
#
#        [[280, 216]],
#
#        [[279, 216]],
#
#        [[278, 216]],
#
#        [[277, 216]],
#
#        [[276, 216]]], dtype=int32), array([[[268, 246]],
#
# ...
#
#        [[621,  24]],
#
#        [[621,  23]],
#
#        [[622,  22]],
#
#        [[622,  21]],
#
#        [[622,  20]],
#
#        [[623,  19]],
#
#        [[623,  18]],
#
#        [[623,  17]],
#
#        [[622,  17]],
#
#        [[621,  17]],
#
#        [[620,  17]],
#
#        [[619,  18]],
#
#        [[619,  19]],
#
#        [[619,  20]],
#
#        [[618,  21]],
#
#        [[617,  20]],
#
#        [[616,  19]],
#
#        [[616,  18]],
#
#        [[616,  17]],
#
#        [[615,  17]],
#
#        [[614,  17]],
#
#        [[613,  17]],
#
#        [[613,  18]],
#
#        [[612,  19]],
#
#        [[611,  18]],
#
#        [[610,  17]],
#
#        [[609,  17]],
#
#        [[608,  17]],
#
#        [[607,  17]],
#
#        [[606,  17]],
#
#        [[605,  17]],
#
#        [[604,  17]],
#
#        [[603,  17]],
#
#        [[602,  17]],
#
#        [[601,  17]],
#
#        [[600,  17]],
#
#        [[599,  17]],
#
#        [[598,  17]],
#
#        [[597,  17]],
#
#        [[596,  18]],
#
#        [[595,  17]],
#
#        [[594,  17]],
#
#        [[593,  17]],
#
#        [[592,  17]],
#
#        [[591,  17]],
#
#        [[590,  17]],
#
#        [[589,  17]],
#
#        [[588,  17]]], dtype=int32), array([[[592,  29]],
#
#        [[593,  28]],
#
#        [[594,  29]],
#
#        [[593,  30]]], dtype=int32), array([[[604,  26]],
#
#        [[605,  25]],
#
#        [[606,  26]],
#
#        [[605,  27]]], dtype=int32), array([[[618,  24]],
#
#        [[619,  23]],
#
#        [[620,  24]],
#
#        [[619,  25]]], dtype=int32), array([[[597,  23]],
#
#        [[598,  22]],
#
#        [[599,  23]],
#
#        [[599,  24]],
#
#        [[599,  25]],
#
#        [[599,  26]],
#
#        [[598,  27]],
#
#        [[597,  26]],
#
#        [[597,  25]],
#
#        [[597,  24]]], dtype=int32), array([[[586,  22]],
#
#        [[587,  21]],
#
#        [[588,  22]],
#
#        [[588,  23]],
#
#        [[587,  24]],
#
#        [[586,  23]]], dtype=int32), array([[[589,  21]],
#
#        [[590,  20]],
#
#        [[591,  21]],
#
#        [[592,  22]],
#
#        [[592,  23]],
#
#        [[591,  24]],
#
#        [[590,  25]],
#
#        [[589,  24]],
#
#        [[589,  23]],
#
#        [[589,  22]]], dtype=int32), array([[[614,  20]],
#
#        [[615,  19]],
#
#        [[616,  20]],
#
#        [[615,  21]]], dtype=int32), array([[[649,  13]],
#
#        [[649,  14]],
#
#        [[649,  15]],
#
#        [[649,  16]],
#
#        [[649,  17]],
#
#        [[649,  18]],
#
#        [[649,  19]],
#
#        [[649,  20]],
#
#        [[649,  21]],
#
#        [[649,  22]],
#
#        [[649,  23]],
#
#        [[649,  24]],
#
#        [[649,  25]],
#
#        [[649,  26]],
#
#        [[649,  27]],
#
#        [[649,  28]],
#
#        [[650,  28]],
#
#        [[651,  28]],
#
#        [[652,  28]],
#
#        [[652,  27]],
#
#        [[653,  26]],
#
#        [[654,  27]],
#
#        [[655,  28]],
#
#        [[656,  28]],
#
#        [[657,  28]],
#
#        [[658,  28]],
#
#        [[659,  28]],
#
#        [[660,  28]],
#
#        [[661,  28]],
#
#        [[662,  28]],
#
#        [[662,  27]],
#
#        [[662,  26]],
#
#        [[663,  25]],
#
#        [[664,  26]],
#
#        [[664,  27]],
#
#        [[665,  27]],
#
#        [[666,  28]],
#
#        [[667,  28]],
#
#        [[668,  28]],
#
#        [[669,  28]],
#
#        [[670,  28]],
#
#        [[671,  28]],
#
#        [[672,  28]],
#
#        [[673,  27]],
#
#        [[674,  28]],
#
#        [[675,  28]],
#
#        [[676,  28]],
#
#        [[677,  28]],
#
#        [[678,  28]],
#
#        [[679,  28]],
#
#        [[680,  28]],
#
#        [[681,  27]],
#
#        [[682,  26]],
#
#        [[682,  25]],
#
#        [[682,  24]],
#
#        [[682,  23]],
#
#        [[681,  22]],
#
#        [[680,  21]],
#
#        [[681,  20]],
#
#        [[681,  19]],
#
#        [[681,  18]],
#
#        [[681,  17]],
#
#        [[680,  17]],
#
#        [[679,  17]],
#
#        [[678,  17]],
#
#        [[677,  17]],
#
#        [[676,  17]],
#
#        [[675,  17]],
#
#        [[674,  18]],
#
#        [[673,  19]],
#
#        [[672,  18]],
#
#        [[671,  17]],
#
#        [[670,  17]],
#
#        [[669,  17]],
#
#        [[668,  17]],
#
#        [[667,  17]],
#
#        [[666,  17]],
#
#        [[665,  17]],
#
#        [[664,  18]],
#
#        [[664,  19]],
#
#        [[663,  20]],
#
#        [[662,  19]],
#
#        [[662,  18]],
#
#        [[662,  17]],
#
#        [[661,  17]],
#
#        [[660,  17]],
#
#        [[659,  17]],
#
#        [[659,  18]],
#
#        [[659,  19]],
#
#        [[659,  20]],
#
#        [[659,  21]],
#
#        [[659,  22]],
#
#        [[659,  23]],
#
#        [[659,  24]],
#
#        [[658,  25]],
#
#        [[657,  25]],
#
#        [[656,  24]],
#
#        [[656,  23]],
#
#        [[656,  22]],
#
#        [[656,  21]],
#
#        [[656,  20]],
#
#        [[656,  19]],
#
#        [[656,  18]],
#
#        [[656,  17]],
#
#        [[655,  17]],
#
#        [[654,  17]],
#
#        [[653,  17]],
#
#        [[652,  16]],
#
#        [[652,  15]],
#
#        [[652,  14]],
#
#        [[652,  13]],
#
#        [[651,  13]],
#
#        [[650,  13]]], dtype=int32), array([[[672,  26]],
#
#        [[673,  25]],
#
#        [[674,  26]],
#
#        [[673,  27]]], dtype=int32), array([[[679,  24]],
#
#        [[680,  23]],
#
#        [[681,  24]],
#
#        [[680,  25]]], dtype=int32), array([[[672,  24]],
#
#        [[673,  23]],
#
#        [[674,  23]],
#
#        [[675,  23]],
#
#        [[676,  24]],
#
#        [[675,  25]],
#
#        [[674,  25]],
#
#        [[673,  25]]], dtype=int32), array([[[664,  24]],
#
#        [[665,  23]],
#
#        [[666,  24]],
#
#        [[665,  25]]], dtype=int32), array([[[664,  22]],
#
#        [[665,  21]],
#
#        [[666,  22]],
#
#        [[665,  23]]], dtype=int32), array([[[670,  20]],
#
#        [[671,  19]],
#
#        [[672,  20]],
#
#        [[671,  21]]], dtype=int32), array([[[665,  19]],
#
#        [[666,  18]],
#
#        [[667,  19]],
#
#        [[666,  20]]], dtype=int32), array([[[576,  13]],
#
#        [[576,  14]],
#
#        [[575,  15]],
#
#        [[575,  16]],
#
#        [[574,  17]],
#
#        [[573,  18]],
#
#        [[572,  17]],
#
#        [[571,  17]],
#
#        [[570,  17]],
#
#        [[569,  17]],
#
#        [[568,  17]],
#
#        [[567,  17]],
#
#        [[566,  17]],
#
#        [[565,  18]],
#
#        [[565,  19]],
#
#        [[564,  20]],
#
#        [[564,  21]],
#
#        [[564,  22]],
#
#        [[564,  23]],
#
#        [[564,  24]],
#
#        [[564,  25]],
#
#        [[565,  26]],
#
#        [[565,  27]],
#
#        [[566,  28]],
#
#        [[567,  28]],
#
#        [[568,  28]],
#
#        [[569,  28]],
#
#        [[570,  28]],
#
#        [[571,  28]],
#
#        [[572,  28]],
#
#        [[573,  27]],
#
#        [[573,  26]],
#
#        [[574,  25]],
#
#        [[575,  26]],
#
#        [[575,  27]],
#
#        [[575,  28]],
#
#        [[576,  28]],
#
#        [[577,  28]],
#
#        [[578,  28]],
#
#        [[578,  27]],
#
#        [[578,  26]],
#
#        [[578,  25]],
#
#        [[578,  24]],
#
#        [[578,  23]],
#
#        [[578,  22]],
#
#        [[578,  21]],
#
#        [[579,  20]],
#
#        [[580,  20]],
#
#        [[581,  19]],
#
#        [[581,  18]],
#
#        [[581,  17]],
#
#        [[580,  16]],
#
#        [[581,  15]],
#
#        [[581,  14]],
#
#        [[581,  13]],
#
#        [[580,  13]],
#
#        [[579,  13]],
#
#        [[578,  13]],
#
#        [[577,  13]]], dtype=int32), array([[[570,  26]],
#
#        [[571,  25]],
#
#        [[572,  26]],
#
#        [[571,  27]]], dtype=int32), array([[[566,  26]],
#
#        [[567,  25]],
#
#        [[568,  26]],
#
#        [[567,  27]]], dtype=int32), array([[[568,  21]],
#
#        [[569,  20]],
#
#        [[570,  21]],
#
#        [[571,  22]],
#
#        [[571,  23]],
#
#        [[570,  24]],
#
#        [[569,  25]],
#
#        [[568,  24]],
#
#        [[567,  23]],
#
#        [[567,  22]]], dtype=int32), array([[[570,  19]],
#
#        [[571,  18]],
#
#        [[572,  19]],
#
#        [[571,  20]]], dtype=int32), array([[[566,  19]],
#
#        [[567,  18]],
#
#        [[568,  19]],
#
#        [[567,  20]]], dtype=int32), array([[[486,  13]],
#
#        [[486,  14]],
#
#        [[486,  15]],
#
#        [[486,  16]],
#
#        [[486,  17]],
#
#        [[486,  18]],
#
#        [[486,  19]],
#
#        [[486,  20]],
#
#        [[486,  21]],
#
#        [[486,  22]],
#
#        [[486,  23]],
#
#        [[486,  24]],
#
#        [[486,  25]],
#
#        [[486,  26]],
#
#        [[486,  27]],
#
#        [[486,  28]],
#
#        [[487,  28]],
#
#        [[488,  28]],
#
#        [[489,  28]],
#
#        [[490,  28]],
#
#        [[491,  28]],
#
#        [[492,  28]],
#
#        [[493,  28]],
#
#        [[494,  28]],
#
#        [[495,  28]],
#
#        [[496,  28]],
#
#        [[497,  28]],
#
#        [[498,  27]],
#
#        [[499,  27]],
#
#        [[500,  28]],
#
#        [[501,  28]],
#
#        [[502,  28]],
#
#        [[503,  28]],
#
#        [[504,  28]],
#
#        [[505,  28]],
#
#        [[506,  27]],
#
#        [[507,  28]],
#
#        [[508,  28]],
#
#        [[509,  28]],
#
#        [[510,  28]],
#
#        [[511,  28]],
#
#        [[512,  28]],
#
#        [[513,  28]],
#
#        [[514,  27]],
#
#        [[514,  26]],
#
#        [[515,  25]],
#
#        [[516,  26]],
#
#        [[516,  27]],
#
#        [[517,  28]],
#
#        [[516,  29]],
#
#        [[516,  30]],
#
#        [[516,  31]],
#
#        [[517,  32]],
#
#        [[518,  32]],
#
#        [[519,  32]],
#
#        [[520,  32]],
#
#        [[521,  32]],
#
#        [[522,  32]],
#
#        [[523,  32]],
#
#        [[524,  31]],
#
#        [[524,  30]],
#
#        [[525,  29]],
#
#        [[526,  28]],
#
#        [[527,  28]],
#
#        [[528,  28]],
#
#        [[529,  28]],
#
#        [[529,  27]],
#
#        [[529,  26]],
#
#        [[529,  25]],
#
#        [[529,  24]],
#
#        [[529,  23]],
#
#        [[530,  22]],
#
#        [[530,  21]],
#
#        [[531,  20]],
#
#        [[532,  20]],
#
#        [[533,  20]],
#
#        [[534,  21]],
#
#        [[533,  22]],
#
#        [[533,  23]],
#
#        [[533,  24]],
#
#        [[533,  25]],
#
#        [[533,  26]],
#
#        [[533,  27]],
#
#        [[534,  28]],
#
#        [[535,  28]],
#
#        [[536,  28]],
#
#        [[537,  28]],
#
#        [[538,  28]],
#
#        [[539,  28]],
#
#        [[540,  28]],
#
#        [[541,  28]],
#
#        [[542,  28]],
#
#        [[543,  28]],
#
#        [[544,  28]],
#
#        [[545,  28]],
#
#        [[546,  28]],
#
#        [[546,  27]],
#
#        [[546,  26]],
#
#        [[546,  25]],
#
#        [[546,  24]],
#
#        [[546,  23]],
#
#        [[546,  22]],
#
#        [[547,  21]],
#
#        [[548,  20]],
#
#        [[549,  21]],
#
#        [[549,  22]],
#
#        [[549,  23]],
#
#        [[549,  24]],
#
#        [[549,  25]],
#
#        [[549,  26]],
#
#        [[549,  27]],
#
#        [[549,  28]],
#
#        [[550,  28]],
#
#        [[551,  28]],
#
#        [[552,  28]],
#
#        [[552,  27]],
#
#        [[552,  26]],
#
#        [[552,  25]],
#
#        [[552,  24]],
#
#        [[552,  23]],
#
#        [[552,  22]],
#
#        [[553,  21]],
#
#        [[554,  20]],
#
#        [[555,  21]],
#
#        [[555,  22]],
#
#        [[555,  23]],
#
#        [[555,  24]],
#
#        [[555,  25]],
#
#        [[555,  26]],
#
#        [[555,  27]],
#
#        [[555,  28]],
#
#        [[556,  28]],
#
#        [[557,  28]],
#
#        [[558,  28]],
#
#        [[558,  27]],
#
#        [[558,  26]],
#
#        [[558,  25]],
#
#        [[558,  24]],
#
#        [[558,  23]],
#
#        [[558,  22]],
#
#        [[558,  21]],
#
#        [[558,  20]],
#
#        [[558,  19]],
#
#        [[557,  18]],
#
#        [[557,  17]],
#
#        [[556,  17]],
#
#        [[555,  17]],
#
#        [[554,  17]],
#
#        [[553,  17]],
#
#        [[552,  17]],
#
#        [[551,  17]],
#
#        [[550,  17]],
#
#        [[549,  17]],
#
#        [[548,  17]],
#
#        [[547,  17]],
#
#        [[546,  17]],
#
#        [[545,  17]],
#
#        [[544,  17]],
#
#        [[543,  17]],
#
#        [[543,  18]],
#
#        [[543,  19]],
#
#        [[542,  20]],
#
#        [[541,  19]],
#
#        [[541,  18]],
#
#        [[540,  17]],
#
#        [[539,  17]],
#
#        [[538,  17]],
#
#        [[537,  17]],
#
#        [[536,  17]],
#
#        [[535,  17]],
#
#        [[534,  17]],
#
#        [[533,  17]],
#
#        [[532,  17]],
#
#        [[531,  17]],
#
#        [[530,  17]],
#
#        [[529,  17]],
#
#        [[528,  17]],
#
#        [[527,  17]],
#
#        [[526,  17]],
#
#        [[525,  17]],
#
#        [[524,  17]],
#
#        [[523,  17]],
#
#        [[522,  17]],
#
#        [[521,  17]],
#
#        [[520,  17]],
#
#        [[519,  17]],
#
#        [[518,  17]],
#
#        [[517,  17]],
#
#        [[516,  18]],
#
#        [[516,  19]],
#
#        [[515,  20]],
#
#        [[514,  19]],
#
#        [[514,  18]],
#
#        [[513,  17]],
#
#        [[512,  17]],
#
#        [[511,  17]],
#
#        [[510,  17]],
#
#        [[509,  17]],
#
#        [[508,  17]],
#
#        [[507,  17]],
#
#        [[506,  18]],
#
#        [[505,  17]],
#
#        [[504,  17]],
#
#        [[503,  17]],
#
#        [[502,  16]],
#
#        [[502,  15]],
#
#        [[502,  14]],
#
#        [[501,  14]],
#
#        [[500,  14]],
#
#        [[499,  15]],
#
#        [[499,  16]],
#
#        [[498,  17]],
#
#        [[497,  17]],
#
#        [[496,  17]],
#
#        [[495,  17]],
#
#        [[494,  17]],
#
#        [[493,  17]],
#
#        [[492,  17]],
#
#        [[491,  17]],
#
#        [[490,  18]],
#
#        [[489,  17]],
#
#        [[489,  16]],
#
#        [[489,  15]],
#
#        [[489,  14]],
#
#        [[489,  13]],
#
#        [[488,  13]],
#
#        [[487,  13]]], dtype=int32), array([[[521,  30]],
#
#        [[522,  29]],
#
#        [[523,  30]],
#
#        [[522,  31]]], dtype=int32), array([[[522,  28]],
#
#        [[523,  27]],
#
#        [[524,  28]],
#
#        [[523,  29]]], dtype=int32), array([[[517,  26]],
#
#        [[518,  25]],
#
#        [[519,  26]],
#
#        [[518,  27]]], dtype=int32), array([[[507,  26]],
#
#        [[508,  25]],
#
#        [[509,  26]],
#
#        [[508,  27]]], dtype=int32), array([[[495,  26]],
#
#        [[496,  25]],
#
#        [[497,  26]],
#
#        [[496,  27]]], dtype=int32), array([[[512,  24]],
#
#        [[513,  23]],
#
#        [[514,  24]],
#
#        [[513,  25]]], dtype=int32), array([[[489,  23]],
#
#        [[490,  22]],
#
#        [[491,  23]],
#
#        [[492,  24]],
#
#        [[491,  25]],
#
#        [[490,  25]],
#
#        [[489,  24]]], dtype=int32), array([[[514,  22]],
#
#        [[515,  21]],
#
#        [[516,  22]],
#
#        [[516,  23]],
#
#        [[515,  24]],
#
#        [[514,  23]]], dtype=int32), array([[[519,  21]],
#
#        [[520,  20]],
#
#        [[521,  21]],
#
#        [[522,  22]],
#
#        [[522,  23]],
#
#        [[521,  24]],
#
#        [[520,  25]],
#
#        [[519,  24]],
#
#        [[518,  23]],
#
#        [[518,  22]]], dtype=int32), array([[[512,  21]],
#
#        [[513,  20]],
#
#        [[514,  21]],
#
#        [[513,  22]]], dtype=int32), array([[[509,  21]],
#
#        [[510,  20]],
#
#        [[511,  21]],
#
#        [[512,  22]],
#
#        [[512,  23]],
#
#        [[511,  24]],
#
#        [[510,  25]],
#
#        [[509,  24]],
#
#        [[508,  23]],
#
#        [[508,  22]]], dtype=int32), array([[[502,  21]],
#
#        [[503,  20]],
#
#        [[504,  20]],
#
#        [[505,  21]],
#
#        [[505,  22]],
#
#        [[505,  23]],
#
#        [[505,  24]],
#
#        [[504,  25]],
#
#        [[503,  25]],
#
#        [[502,  24]],
#
#        [[502,  23]],
#
#        [[502,  22]]], dtype=int32), array([[[496,  21]],
#
#        [[497,  20]],
#
#        [[498,  20]],
#
#        [[499,  21]],
#
#        [[498,  22]],
#
#        [[497,  22]]], dtype=int32), array([[[517,  19]],
#
#        [[518,  18]],
#
#        [[519,  19]],
#
#        [[518,  20]]], dtype=int32), array([[[507,  19]],
#
#        [[508,  18]],
#
#        [[509,  19]],
#
#        [[508,  20]]], dtype=int32), array([[[491,  19]],
#
#        [[492,  18]],
#
#        [[493,  19]],
#
#        [[492,  20]]], dtype=int32), array([[[475,  13]],
#
#        [[475,  14]],
#
#        [[475,  15]],
#
#        [[475,  16]],
#
#        [[475,  17]],
#
#        [[475,  18]],
#
#        [[475,  19]],
#
#        [[475,  20]],
#
#        [[475,  21]],
#
#        [[475,  22]],
#
#        [[475,  23]],
#
#        [[475,  24]],
#
#        [[475,  25]],
#
#        [[475,  26]],
#
#        [[475,  27]],
#
#        [[475,  28]],
#
#        [[476,  28]],
#
#        [[477,  28]],
#
#        [[478,  28]],
#
#        [[478,  27]],
#
#        [[478,  26]],
#
#        [[478,  25]],
#
#        [[478,  24]],
#
#        [[478,  23]],
#
#        [[478,  22]],
#
#        [[479,  21]],
#
#        [[480,  20]],
#
#        [[481,  21]],
#
#        [[481,  22]],
#
#        [[481,  23]],
#
#        [[481,  24]],
#
#        [[481,  25]],
#
#        [[481,  26]],
#
#        [[481,  27]],
#
#        [[481,  28]],
#
#        [[482,  28]],
#
#        [[483,  28]],
#
#        [[484,  28]],
#
#        [[484,  27]],
#
#        [[484,  26]],
#
#        [[484,  25]],
#
#        [[484,  24]],
#
#        [[484,  23]],
#
#        [[484,  22]],
#
#        [[484,  21]],
#
#        [[484,  20]],
#
#        [[484,  19]],
#
#        [[484,  18]],
#
#        [[483,  17]],
#
#        [[482,  17]],
#
#        [[481,  17]],
#
#        [[480,  17]],
#
#        [[479,  17]],
#
#        [[478,  16]],
#
#        [[478,  15]],
#
#        [[478,  14]],
#
#        [[478,  13]],
#
#        [[477,  13]],
#
#        [[476,  13]]], dtype=int32), array([[[481,  19]],
#
#        [[482,  18]],
#
#        [[483,  19]],
#
#        [[482,  20]]], dtype=int32))

# %%
otsuTh = threshold_otsu(imgGray)
print(otsuTh)
binary = imgGray > otsuTh

plt.figure(figsize=(20,50))
pl.subplots_adjust(right=1)
plt.subplots_adjust(right=1)

plt.subplot(1, 3, 1)
plt.imshow(imgGray, cmap='gray')
plt.title('GrayScale');

plt.subplot(1, 3, 2)
plt.imshow(binary, cmap='gray')
plt.title('Image Binarized');

plt.subplot(1, 3, 3)
plt.imshow(~binary, cmap='gray')
plt.title('Image Binarized | Compliment');
# Out:
# 166

# %%
# apply Otsu's automatic thresholding which automatically determines
# the best threshold value
(T, threshInv) = cv2.threshold(imgGray, 0, 256, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
print(T)

plt.figure(figsize=(20, 50))
plt.subplot(1, 2, 1)
plt.imshow(threshInv, cmap='gray')
plt.title('s')

masked = cv2.bitwise_and(imgRGB, imgRGB, mask=threshInv)
plt.subplot(1, 2, 2)
plt.imshow(masked)

#cv2.imshow("Output", masked)
# Out:
# 166.0
